# %%
# imports needed for translation:

import whisper
from whisper.utils import get_writer
import yt_dlp
import ffmpeg
import tqdm
import sys
import torch
import re
import gc
import os
# Out:
# c:\Users\melis\.conda\envs\loqio-env\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.2.0)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(

# %%
# grabbing audio file from youtube video and saving as m4a
def get_yt_audio(yt_url):
    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'm4a',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([yt_url])

    print(error_code)

# grabbing subtitles only if youtube video has them and saving as srt
def get_yt_subtitles(yt_url):
    ydl_opts = {
        'writesubtitles': True,
        # 'writeautomaticsub': True,
        'subtitlesformat': 'srt',
        'skip_download': True,
        'outtmpl': '%(id)s.%(ext)s',
        'no_cache': True,
        # 'subtitleslangs': ['en','zh-Hans'],
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([yt_url])
    
    print(error_code)

# %% [markdown]
# ### 5. Translate transcript to english (this runs after transcription code creates the json formatted transcription)

# %%
# Define a custom tqdm class
class _CustomProgressBar(tqdm.tqdm):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._current = self.n

    def update(self, n):
        super().update(n)
        self._current += n
        # Add your custom progress handling here (e.g., updating a GUI)
        # print(f"Progress: {self._current}/{self.total}") # Optional: for console output

def extract_yt_video_id(yt_url):
    # Extract the video ID from the YouTube URL
    if "v=" in yt_url:
        return yt_url.split("v=")[-1].split("&")[0]
    elif "youtu.be/" in yt_url:
        return yt_url.split("youtu.be/")[-1].split("?")[0]
    else:
        raise ValueError("Invalid YouTube URL")
    
def translate_audio(file, language, target_language):
    translate_module = sys.modules['whisper.transcribe']
    translate_module.tqdm.tqdm = _CustomProgressBar

    model = whisper.load_model("large-v2")
    decode_options = {
    "language": language,
    "verbose": False, # verbose=False is often required for the progress bar to appear/callback to work
    }
    model_opt = dict(task="translate", **decode_options)
    result = model.transcribe(file, **model_opt)
    writer = get_writer("srt", ".")
    yt_video_id = file.split(".")[0]  # Assuming the file is named as "{video_id}.m4a"
    writer(result, f"{yt_video_id}-{target_language}.srt")
    for segment in result['segments']:
        print(f"[{segment['start']:.2f}s -> {segment['end']:.2f}s] {segment['text']}")

    del model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# %%
translate_audio("oIoy02pDgoU.m4a","zh", "en")
# Out:
# c:\Users\melis\.conda\envs\loqio-env\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  98%|█████████▊| 271459/277459 [59:14<01:18, 76.37frames/s]
# [0.00s -> 5.00s]  YoYo English Channel YouTube
# [30.00s -> 39.00s]  Have you finished reading it?
# [39.00s -> 41.00s]  Tell me, you are so objective.
# [50.00s -> 51.00s]  Who is that?
# [51.00s -> 52.00s]  You tell me.
# [52.00s -> 63.00s]  Among these ten projects, there are four rebirths, three transgressions, and two open systems.
# [63.00s -> 65.00s]  I think it's a bit of a one-way street.
# [65.00s -> 66.00s]  Isn't that only nine?
# [66.00s -> 67.00s]  What about the other one?
# [67.00s -> 71.00s]  This bookworm is old and outdated.
# [71.00s -> 73.00s]  It's easy to make people tongue-tied.
# [76.00s -> 79.00s]  But the boss has bought all the books.
# ...

# %%
translate_audio("Q04CzDIZ5T4.m4a", "zh")
# Out:
# c:\Users\melis\.conda\envs\loqio-env\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|█████████▉| 605314/608314 [1:26:58<00:25, 115.99frames/s]
# [31.00s -> 33.58s]  at this peak
# [33.84s -> 35.74s]  the story took light step
# [35.76s -> 37.82s]  and was reverberated
# [37.82s -> 40.36s]  it's amazing
# [40.96s -> 43.52s]  this is the unedicted
# [43.52s -> 45.06s]  the road to Mars
# [49.14s -> 50.94s]  it's calm
# [50.94s -> 51.16s]  and grounds Alpa
# [51.16s -> 52.56s]  on a distance
# [52.92s -> 54.28s]  Circling the Huaxia continent
# [54.28s -> 56.22s]  and coexisting with the Great Lakes
# [56.26s -> 57.34s] ��앙
# [57.44s -> 58.56s]  brought a perfect change
# [58.56s -> 59.56s]  Snow mountain.
# [61.56s -> 62.56s]  It's really beautiful.
# [63.56s -> 65.56s]  You have to see the scenery here with your eyes.
# ...

# %%
translate_audio("oLHfnK9IVZs.m4a", "zh")
# Out:
# c:\Users\melis\.conda\envs\loqio-env\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|██████████| 95912/95912 [08:26<00:00, 189.22frames/s]
# [0.00s -> 27.00s]  早上好,我是佳佳。 Good morning, I'm Jia Jia.
# [28.00s -> 34.00s]  我刚刚送了我的女儿去托儿所, I just sent my daughter to the nursery,
# [34.00s -> 39.00s]  然后回家化了一个妆。 and then I went home and put on a makeup.
# [39.00s -> 44.00s]  现在我准备做早餐。 Now I'm going to make breakfast.
# [44.00s -> 50.00s]  今天我打算做我最喜欢的早餐。 Today I'm going to make my favorite breakfast.
# [50.00s -> 54.00s]  需要的食材很简单。 The ingredients are very simple.
# [54.00s -> 62.00s]  牛油果,吐司,鸡蛋和黄油。 Butter, avocado, toast, eggs and butter.
# [62.00s -> 66.00s]  那我们先烤面包吧。 Let's bake the bread first.
# [70.00s -> 73.00s]  现在打一个鸡蛋。 Now I'm going to beat an egg.
# [73.00s -> 86.00s]  现在开始煎蛋。 Now I'm going to fry the eggs.
# ...

# %%
transcript = [{'index': '1',
  'start_time': '00:00:00.000',
  'end_time': '00:00:27.000',
  'text': '早上好,我是佳佳。'},
 {'index': '2',
  'start_time': '00:00:27.000',
  'end_time': '00:00:34.000',
  'text': '我刚刚送了我的女儿去托儿所,'},
 {'index': '3',
  'start_time': '00:00:34.000',
  'end_time': '00:00:39.000',
  'text': '然后回家化了一个妆。'},
 {'index': '4',
  'start_time': '00:00:39.000',
  'end_time': '00:00:44.000',
  'text': '现在我准备做早餐。'},
 {'index': '5',
  'start_time': '00:00:44.000',
  'end_time': '00:00:50.000',
  'text': '今天我打算做我最喜欢的早餐。'},
 {'index': '6',
  'start_time': '00:00:50.000',
  'end_time': '00:00:54.000',
  'text': '需要的食材很简单。'},
 {'index': '7',
  'start_time': '00:00:54.000',
  'end_time': '00:01:02.000',
  'text': '牛油果、吐司、鸡蛋和黄油。'},
 {'index': '8',
  'start_time': '00:01:02.000',
  'end_time': '00:01:06.000',
  'text': '那我们先烤面包吧。'},
 {'index': '9',
  'start_time': '00:01:09.000',
  'end_time': '00:01:12.000',
  'text': '现在打一个鸡蛋。'},
 {'index': '10',
  'start_time': '00:01:12.000',
  'end_time': '00:01:25.000',
  'text': '现在开始煎蛋。'},
 {'index': '11',
  'start_time': '00:01:25.000',
  'end_time': '00:01:32.000',
  'text': '放一点黄油。'},
 {'index': '12',
  'start_time': '00:01:32.000',
  'end_time': '00:01:37.000',
  'text': '黄油融化以后,把蛋倒进去。'},
 {'index': '13',
  'start_time': '00:01:37.000',
  'end_time': '00:01:47.000',
  'text': '搅拌一下。'},
 {'index': '14',
  'start_time': '00:01:47.000',
  'end_time': '00:01:52.000',
  'text': '接下来就很简单了。'},
 {'index': '15',
  'start_time': '00:01:52.000',
  'end_time': '00:01:56.000',
  'text': '把牛油果抹上去。'},
 {'index': '16',
  'start_time': '00:01:56.000',
  'end_time': '00:02:10.000',
  'text': '哇,这个牛油果果核好大,可以用来水培。'},
 {'index': '17',
  'start_time': '00:02:10.000',
  'end_time': '00:02:24.000',
  'text': '然后再把鸡蛋放上去。'},
 {'index': '18',
  'start_time': '00:02:24.000',
  'end_time': '00:02:30.000',
  'text': '放一点黑胡椒。'},
 {'index': '19',
  'start_time': '00:02:30.000',
  'end_time': '00:02:36.000',
  'text': '放一点盐。'},
 {'index': '20',
  'start_time': '00:02:36.000',
  'end_time': '00:02:40.000',
  'text': '放一点黑胡椒。'},
 {'index': '21',
  'start_time': '00:02:40.000',
  'end_time': '00:02:46.000',
  'text': '我个人还喜欢放一点辣椒酱。'},
 {'index': '22',
  'start_time': '00:02:46.000',
  'end_time': '00:02:49.000',
  'text': '因为我喜欢吃辣。'},
 {'index': '23',
  'start_time': '00:02:49.000',
  'end_time': '00:02:53.000',
  'text': '放在盘子里。'},
 {'index': '24',
  'start_time': '00:02:53.000',
  'end_time': '00:02:56.000',
  'text': '现在做一杯咖啡。'},
 {'index': '25',
  'start_time': '00:02:56.000',
  'end_time': '00:03:03.000',
  'text': '这种咖啡壶大家都知道吧。'},
 {'index': '26',
  'start_time': '00:03:03.000',
  'end_time': '00:03:10.000',
  'text': '煮咖啡也很简单,只有几个步骤。'},
 {'index': '27',
  'start_time': '00:03:10.000',
  'end_time': '00:03:17.000',
  'text': '第一,倒水。'},
 {'index': '28',
  'start_time': '00:03:17.000',
  'end_time': '00:03:27.000',
  'text': '第二,放咖啡粉。'},
 {'index': '29',
  'start_time': '00:03:27.000',
  'end_time': '00:03:31.000',
  'text': '抖一下。'},
 {'index': '30',
  'start_time': '00:03:31.000',
  'end_time': '00:03:35.000',
  'text': '第三,放进去。'},
 {'index': '31',
  'start_time': '00:03:35.000',
  'end_time': '00:03:42.000',
  'text': '然后关上。'},
 {'index': '32',
  'start_time': '00:03:42.000',
  'end_time': '00:03:48.000',
  'text': '开火。'},
 {'index': '33',
  'start_time': '00:03:48.000',
  'end_time': '00:03:58.000',
  'text': '等个一两分钟。'},
 {'index': '34',
  'start_time': '00:03:58.000',
  'end_time': '00:04:05.000',
  'text': '好了。'},
 {'index': '35',
  'start_time': '00:04:05.000',
  'end_time': '00:04:10.000',
  'text': '倒进咖啡杯。'},
 {'index': '36',
  'start_time': '00:04:10.000',
  'end_time': '00:04:15.000',
  'text': '这是我的早餐。'},
 {'index': '37',
  'start_time': '00:04:15.000',
  'end_time': '00:04:18.000',
  'text': '那我开始享用啦。'},
 {'index': '38',
  'start_time': '00:04:28.000',
  'end_time': '00:04:42.000',
  'text': '我喜欢吃咖啡。'},
 {'index': '39',
  'start_time': '00:04:42.000',
  'end_time': '00:04:51.000',
  'text': '飞过来一只蜜蜂。'},
 {'index': '40',
  'start_time': '00:04:51.000',
  'end_time': '00:04:53.000',
  'text': '怎么办?'},
 {'index': '41',
  'start_time': '00:04:53.000',
  'end_time': '00:04:57.000',
  'text': '这咖啡还能喝吗?'},
 {'index': '42',
  'start_time': '00:04:57.000',
  'end_time': '00:05:02.000',
  'text': '我怕它咬我。'},
 {'index': '43',
  'start_time': '00:05:02.000',
  'end_time': '00:05:07.000',
  'text': '我先走了。'},
 {'index': '44',
  'start_time': '00:05:07.000',
  'end_time': '00:05:13.000',
  'text': '吃完早饭后,洗碗。'},
 {'index': '45',
  'start_time': '00:05:13.000',
  'end_time': '00:05:19.000',
  'text': '给植物喷水。'},
 {'index': '46',
  'start_time': '00:05:19.000',
  'end_time': '00:05:23.000',
  'text': '这个植物中文叫发财树。'},
 {'index': '47',
  'start_time': '00:05:23.000',
  'end_time': '00:05:25.000',
  'text': '它长新叶子了。'},
 {'index': '48',
  'start_time': '00:05:25.000',
  'end_time': '00:05:35.000',
  'text': '是不是暗示我要发财了?'},
 {'index': '49',
  'start_time': '00:05:35.000',
  'end_time': '00:05:46.000',
  'text': '然后躺在沙发上刷剧。'},
 {'index': '50',
  'start_time': '00:05:46.000',
  'end_time': '00:05:53.000',
  'text': '《The Good Wife》是我最喜欢的美剧之一。'},
 {'index': '51',
  'start_time': '00:05:53.000',
  'end_time': '00:05:56.000',
  'text': '在我没有动力的时候,'},
 {'index': '52',
  'start_time': '00:05:56.000',
  'end_time': '00:06:00.000',
  'text': '或者我不知道看什么的时候,'},
 {'index': '53',
  'start_time': '00:06:00.000',
  'end_time': '00:06:05.000',
  'text': '我常常把它找出来再看一遍。'},
 {'index': '54',
  'start_time': '00:06:05.000',
  'end_time': '00:06:11.000',
  'text': '我可能已经看了六遍、七遍了吧。'},
 {'index': '55',
  'start_time': '00:06:11.000',
  'end_time': '00:06:21.000',
  'text': '我觉得女主角Alicia是一个很真实、很饱满的角色。'},
 {'index': '56',
  'start_time': '00:06:21.000',
  'end_time': '00:06:24.000',
  'text': '她友好、友坏。'},
 {'index': '57',
  'start_time': '00:06:24.000',
  'end_time': '00:06:27.000',
  'text': '她非常有野心,'},
 {'index': '58',
  'start_time': '00:06:27.000',
  'end_time': '00:06:30.000',
  'text': '有时候也有一点自私。'},
 {'index': '59',
  'start_time': '00:06:30.000',
  'end_time': '00:06:34.000',
  'text': '她的人生大起大落,'},
 {'index': '60',
  'start_time': '00:06:34.000',
  'end_time': '00:06:40.000',
  'text': '看她一步一步一步成长起来的样子,'},
 {'index': '61',
  'start_time': '00:06:40.000',
  'end_time': '00:06:43.000',
  'text': '给我很大的鼓舞。'},
 {'index': '62',
  'start_time': '00:06:43.000',
  'end_time': '00:06:48.000',
  'text': '那现在我准备去做午饭了。'},
 {'index': '63',
  'start_time': '00:06:49.000',
  'end_time': '00:06:52.000',
  'text': '我其实不是很饿,'},
 {'index': '64',
  'start_time': '00:06:52.000',
  'end_time': '00:06:58.000',
  'text': '所以我做一个简单的沙拉就好了。'},
 {'index': '65',
  'start_time': '00:06:58.000',
  'end_time': '00:07:02.000',
  'text': '这个沙拉非常简单,'},
 {'index': '66',
  'start_time': '00:07:02.000',
  'end_time': '00:07:06.000',
  'text': '需要一个西红柿,'},
 {'index': '67',
  'start_time': '00:07:06.000',
  'end_time': '00:07:09.000',
  'text': '一个马苏里拉,'},
 {'index': '68',
  'start_time': '00:07:09.000',
  'end_time': '00:07:10.000',
  'text': '奶酪球,'},
 {'index': '69',
  'start_time': '00:07:10.000',
  'end_time': '00:07:13.000',
  'text': '一点罗勒叶。'},
 {'index': '70',
  'start_time': '00:07:13.000',
  'end_time': '00:07:16.000',
  'text': '好,开始。'},
 {'index': '71',
  'start_time': '00:07:16.000',
  'end_time': '00:07:22.000',
  'text': '西红柿切成一块一块的。'},
 {'index': '72',
  'start_time': '00:07:33.000',
  'end_time': '00:07:37.000',
  'text': '马苏里拉也切块。'},
 {'index': '73',
  'start_time': '00:07:47.000',
  'end_time': '00:07:54.000',
  'text': '然后把它们一个一个放好。'},
 {'index': '74',
  'start_time': '00:08:04.000',
  'end_time': '00:08:10.000',
  'text': '放罗勒叶起一个装饰作用。'},
 {'index': '75',
  'start_time': '00:08:17.000',
  'end_time': '00:08:20.000',
  'text': '一点点醋,'},
 {'index': '76',
  'start_time': '00:08:22.000',
  'end_time': '00:08:25.000',
  'text': '一点橄榄油,'},
 {'index': '77',
  'start_time': '00:08:27.000',
  'end_time': '00:08:30.000',
  'text': '一点黑胡椒。'},
 {'index': '78',
  'start_time': '00:08:34.000',
  'end_time': '00:08:36.000',
  'text': '好了。'},
 {'index': '79',
  'start_time': '00:08:36.000',
  'end_time': '00:08:41.000',
  'text': '快吧,不到五分钟就做好了。'},
 {'index': '80',
  'start_time': '00:08:41.000',
  'end_time': '00:08:44.000',
  'text': '喝这个水。'},
 {'index': '81',
  'start_time': '00:08:46.000',
  'end_time': '00:08:49.000',
  'text': '喝水。'},
 {'index': '82',
  'start_time': '00:09:09.000',
  'end_time': '00:09:13.000',
  'text': '因为晚上要做中餐,'},
 {'index': '83',
  'start_time': '00:09:13.000',
  'end_time': '00:09:17.000',
  'text': '所以现在我去超市买一点菜。'},
 {'index': '84',
  'start_time': '00:09:17.000',
  'end_time': '00:09:20.000',
  'text': '对了,我剪头发了,'},
 {'index': '85',
  'start_time': '00:09:20.000',
  'end_time': '00:09:23.000',
  'text': '你们看出来吗?'},
 {'index': '86',
  'start_time': '00:09:23.000',
  'end_time': '00:09:26.000',
  'text': '比以前短了很多,'},
 {'index': '87',
  'start_time': '00:09:26.000',
  'end_time': '00:09:30.000',
  'text': '因为之前真的太长了,'},
 {'index': '88',
  'start_time': '00:09:30.000',
  'end_time': '00:09:33.000',
  'text': '洗头和吹头发很累。'},
 {'index': '89',
  'start_time': '00:09:33.000',
  'end_time': '00:09:40.000',
  'text': '这个是在一个日本的理发店剪的。'},
 {'index': '90',
  'start_time': '00:09:40.000',
  'end_time': '00:09:46.000',
  'text': '我告诉他我要高层次的中长发,'},
 {'index': '91',
  'start_time': '00:09:46.000',
  'end_time': '00:09:55.000',
  'text': '然后我给他看了老友记里面Rachel的照片作为参考。'},
 {'index': '92',
  'start_time': '00:09:55.000',
  'end_time': '00:09:58.000',
  'text': '你们觉得怎么样?'},
 {'index': '93',
  'start_time': '00:09:58.000',
  'end_time': '00:10:02.000',
  'text': '好,现在出发吧。'},
 {'index': '94',
  'start_time': '00:10:10.000',
  'end_time': '00:10:13.000',
  'text': '中餐时间。'},
 {'index': '95',
  'start_time': '00:10:31.000',
  'end_time': '00:10:34.000',
  'text': '在中超买了一些食材,'},
 {'index': '96',
  'start_time': '00:10:34.000',
  'end_time': '00:10:39.000',
  'text': '又去DM买了一些孩子的零食。'},
 {'index': '97',
  'start_time': '00:10:39.000',
  'end_time': '00:10:44.000',
  'text': '每次买菜看起来都好狼狈。'},
 {'index': '98',
  'start_time': '00:10:44.000',
  'end_time': '00:10:49.000',
  'text': '好重啊,我的肩膀好痛。'},
 {'index': '99',
  'start_time': '00:10:58.000',
  'end_time': '00:11:03.000',
  'text': '赶紧把菜放进冰箱。'},
 {'index': '100',
  'start_time': '00:11:10.000',
  'end_time': '00:11:15.000',
  'text': '我马上要去托儿所接我的女儿,'},
 {'index': '101',
  'start_time': '00:11:15.000',
  'end_time': '00:11:20.000',
  'text': '但是我们不会马上回家。'},
 {'index': '102',
  'start_time': '00:11:20.000',
  'end_time': '00:11:26.000',
  'text': '我打算带她去儿童游乐场放一下电。'},
 {'index': '103',
  'start_time': '00:11:26.000',
  'end_time': '00:11:31.000',
  'text': '我听到她说她要去托儿所,'},
 {'index': '104',
  'start_time': '00:11:31.000',
  'end_time': '00:11:34.000',
  'text': '她说她要去托儿所。'},
 {'index': '105',
  'start_time': '00:11:35.000',
  'end_time': '00:11:38.000',
  'text': '消停结束。'},
 {'index': '106',
  'start_time': '00:11:38.000',
  'end_time': '00:11:41.000',
  'text': 'Kathy时间到。'},
 {'index': '107',
  'start_time': '00:11:41.000',
  'end_time': '00:11:57.400',
  'text': '我在家里也很豪'},
 {'index': '108',
  'start_time': '00:11:57.400',
  'end_time': '00:12:01.400',
  'text': '通常我要洗两遍。'},
 {'index': '109',
  'start_time': '00:12:07.400',
  'end_time': '00:12:09.400',
  'text': '然后放水。'},
 {'index': '110',
  'start_time': '00:12:15.400',
  'end_time': '00:12:18.400',
  'text': '在里面你可以看到'},
 {'index': '111',
  'start_time': '00:12:18.400',
  'end_time': '00:12:20.400',
  'text': '它会告诉你'},
 {'index': '112',
  'start_time': '00:12:20.400',
  'end_time': '00:12:23.400',
  'text': '如果水有水分的话'},
 {'index': '113',
  'start_time': '00:12:23.400',
  'end_time': '00:12:25.400',
  'text': '它会告诉你'},
 {'index': '114',
  'start_time': '00:12:25.400',
  'end_time': '00:12:28.400',
  'text': '如果是煮米饭'},
 {'index': '115',
  'start_time': '00:12:28.400',
  'end_time': '00:12:32.400',
  'text': '两杯米应该放多少水。'},
 {'index': '116',
  'start_time': '00:12:34.400',
  'end_time': '00:12:38.400',
  'text': '选择米饭,然后倒计时。'},
 {'index': '117',
  'start_time': '00:12:49.400',
  'end_time': '00:12:52.400',
  'text': '这样两个半小时以后'},
 {'index': '118',
  'start_time': '00:12:52.400',
  'end_time': '00:12:54.400',
  'text': '它就煮好了。'},
 {'index': '119',
  'start_time': '00:12:56.400',
  'end_time': '00:12:58.400',
  'text': '那我出门啦。'},
 {'index': '120',
  'start_time': '00:13:17.400',
  'end_time': '00:13:21.400',
  'text': '结果晚上还是没有吃中餐。'},
 {'index': '121',
  'start_time': '00:13:21.400',
  'end_time': '00:13:25.400',
  'text': '临时决定吃泰国咖喱。'},
 {'index': '122',
  'start_time': '00:13:25.400',
  'end_time': '00:13:26.400',
  'text': '因为'},
 {'index': '123',
  'start_time': '00:13:31.400',
  'end_time': '00:13:34.400',
  'text': '因为我们发现还有半包'},
 {'index': '124',
  'start_time': '00:13:34.400',
  'end_time': '00:13:38.400',
  'text': '上次剩下的调味料没有用。'},
 {'index': '125',
  'start_time': '00:13:38.400',
  'end_time': '00:13:40.400',
  'text': '哄完孩子睡觉'},
 {'index': '126',
  'start_time': '00:13:40.400',
  'end_time': '00:13:44.400',
  'text': '上楼发现今天的晚霞好美。'},
 {'index': '127',
  'start_time': '00:13:44.400',
  'end_time': '00:13:49.400',
  'text': '孩子睡着了,我打算犒劳一下自己。'},
 {'index': '128',
  'start_time': '00:13:49.400',
  'end_time': '00:13:54.400',
  'text': '吃一个冰淇淋,喝一个小酒。'},
 {'index': '129',
  'start_time': '00:14:14.400',
  'end_time': '00:14:16.400',
  'text': '还要吗?'},
 {'index': '130',
  'start_time': '00:14:17.400',
  'end_time': '00:14:19.400',
  'text': '再来一勺吧。'},
 {'index': '131',
  'start_time': '00:14:20.400',
  'end_time': '00:14:21.400',
  'text': '三勺。'},
 {'index': '132',
  'start_time': '00:14:22.400',
  'end_time': '00:14:23.400',
  'text': '够了。'},
 {'index': '133',
  'start_time': '00:14:29.400',
  'end_time': '00:14:31.400',
  'text': '再搞一个氛围感。'},
 {'index': '134',
  'start_time': '00:14:34.400',
  'end_time': '00:14:36.400',
  'text': '点一个蜡烛。'},
 {'index': '135',
  'start_time': '00:14:45.400',
  'end_time': '00:14:48.400',
  'text': '宵夜开始。'},
 {'index': '136',
  'start_time': '00:14:48.400',
  'end_time': '00:14:51.400',
  'text': '还是要找一个视频看。'},
 {'index': '137',
  'start_time': '00:14:51.400',
  'end_time': '00:14:57.400',
  'text': '给大家推荐一个我很喜欢的YouTuber。'},
 {'index': '138',
  'start_time': '00:14:57.400',
  'end_time': '00:15:00.400',
  'text': '叫Little Chinese Everywhere。'},
 {'index': '139',
  'start_time': '00:15:00.400',
  'end_time': '00:15:05.400',
  'text': '他有很多在中国旅游的视频。'},
 {'index': '140',
  'start_time': '00:15:05.400',
  'end_time': '00:15:07.400',
  'text': '非常好。'},
 {'index': '141',
  'start_time': '00:15:07.400',
  'end_time': '00:15:09.400',
  'text': '推荐大家看一下。'},
 {'index': '142',
  'start_time': '00:15:09.400',
  'end_time': '00:15:10.400',
  'text': '这个节目也很好。'},
 {'index': '143',
  'start_time': '00:15:10.400',
  'end_time': '00:15:11.400',
  'text': '谢谢啊。'},
 {'index': '144',
  'start_time': '00:15:11.400',
  'end_time': '00:15:12.400',
  'text': '好,谢谢啊。'},
 {'index': '145',
  'start_time': '00:15:12.400',
  'end_time': '00:15:15.400',
  'text': '这边的话就先回那边吧。'},
 {'index': '146',
  'start_time': '00:15:15.400',
  'end_time': '00:15:17.400',
  'text': '好的,好的,好的,好的,请。'},
 {'index': '147',
  'start_time': '00:15:17.400',
  'end_time': '00:15:19.400',
  'text': '那我们跟你一起走还是在这儿走?'},
 {'index': '148',
  'start_time': '00:15:26.400',
  'end_time': '00:15:30.400',
  'text': '那今天的视频就到这里了。'},
 {'index': '149',
  'start_time': '00:15:30.400',
  'end_time': '00:15:32.400',
  'text': '谢谢你的观看。'},
 {'index': '150',
  'start_time': '00:15:32.400',
  'end_time': '00:15:37.400',
  'text': '如果你有什么想看的视频内容,'},
 {'index': '151',
  'start_time': '00:15:37.400',
  'end_time': '00:15:40.400',
  'text': '也欢迎留言告诉我。'},
 {'index': '152',
  'start_time': '00:15:40.400',
  'end_time': '00:15:42.400',
  'text': '我们下次再见。'},
 {'index': '153',
  'start_time': '00:15:42.400',
  'end_time': '00:15:44.400',
  'text': '再见。'}]

# %%
transcript = [
 {'index': '1',
  'start_time': '00:00:00.000',
  'end_time': '00:00:27.000',
  'text': '如果你有什么想看的视频内容,'},
 {'index': '2',
  'start_time': '00:00:27.000',
  'end_time': '00:00:34.000',
  'text': '也欢迎留言告诉我。'},
 {'index': '3',
  'start_time': '00:00:34.000',
  'end_time': '00:00:39.000',
  'text': '我们下次再见。'}
]

# %%
translate_transcript(transcript, "Mandarin", "English")
# Out:
# 112 153
# 42 153
# 21 153
# 86 153
# 10 153
# 59 153
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# File c:\Users\melis\.conda\envs\loqio-env\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\melis\.conda\envs\loqio-env\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\melis\.conda\envs\loqio-env\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
# ...

# %%
def parse_translation_srt(srt):
    with open(srt, "r", encoding="utf-8") as f:
        srt_content = f.read()

    content = srt_content.replace('\r\n', '\n').strip()
    blocks = re.split(r'\n\n+', content)
    transcript = []

    for block in blocks:
        lines = block.split('\n')
        if (len(lines) >= 3):
            index = lines[0].strip()

            times = lines[1].split(' --> ')

            if (len(times) == 2):
                text = " ".join(lines[2:]).strip()
                transcript.append({
                    "index": index,
                    "start_time": times[0].strip().replace(',', '.'),
                    "end_time": times[1].strip().replace(',', '.'),
                    "text": text
                })

    return transcript

# %%
def translate_video(yt_url, language, target_language):
    video_id = extract_yt_video_id(yt_url)
    
    if not os.path.exists(f"{video_id}.m4a"):
        get_yt_audio(yt_url)
        audio_file = f"{video_id}.m4a"

    translate_audio(audio_file, language, target_language)
    srt_file = f"{video_id}-{target_language}.srt"
    transcript = parse_translation_srt(srt_file)
    return transcript

# %%
translate_video("https://www.youtube.com/watch?v=oIoy02pDgoU", "zh", "en")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oIoy02pDgoU
# [youtube] oIoy02pDgoU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] oIoy02pDgoU: Downloading android vr player API JSON
# [info] oIoy02pDgoU: Downloading 1 format(s): 140
# [download] Destination: oIoy02pDgoU.m4a
# [download] 100% of   42.82MiB in 00:00:01 at 29.72MiB/s
# [FixupM4a] Correcting container of "oIoy02pDgoU.m4a"
# [ExtractAudio] Not converting audio oIoy02pDgoU.m4a; file is already in target format m4a
# 0
# c:\Users\melis\.conda\envs\loqio-env\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
# ...
